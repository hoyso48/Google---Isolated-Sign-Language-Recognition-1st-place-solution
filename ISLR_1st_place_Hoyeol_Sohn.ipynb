# %%
cd ./drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !pip install -q tensorflow-addons
# !pip install -q git+https://github.com/hoyso48/tf-utils@main
# Out:
#   Preparing metadata (setup.py) ... done

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import matplotlib as mpl
import tensorflow.keras.mixed_precision as mixed_precision

from tqdm.autonotebook import tqdm
import sklearn

from tf_utils.schedules import OneCycleLR, ListedLR
from tf_utils.callbacks import Snapshot, SWA
from tf_utils.learners import FGM, AWP

import os
import time
import pickle
import math
import random
import sys
import cv2
import gc
import glob
import datetime

print(f'Tensorflow Version: {tf.__version__}')
print(f'Python Version: {sys.version}')
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# <ipython-input-3-f8b6455d81d0>:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Tensorflow Version: 2.12.0
# Python Version: 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]

# %%
# Seed all random number generators
def seed_everything(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
def get_strategy(device='TPU'):
    if "TPU" in device:
        tpu = 'local' if device=='TPU-VM' else None
        print("connecting to TPU...")
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect(tpu=tpu)
        strategy = tf.distribute.TPUStrategy(tpu)
        IS_TPU = True

    if device == "GPU"  or device=="CPU":
        ngpu = len(tf.config.experimental.list_physical_devices('GPU'))
        if ngpu>1:
            print("Using multi GPU")
            strategy = tf.distribute.MirroredStrategy()
        elif ngpu==1:
            print("Using single GPU")
            strategy = tf.distribute.get_strategy()
        else:
            print("Using CPU")
            strategy = tf.distribute.get_strategy()
            CFG.device = "CPU"

    if device == "GPU":
        print("Num GPUs Available: ", ngpu)

    AUTO     = tf.data.experimental.AUTOTUNE
    REPLICAS = strategy.num_replicas_in_sync
    print(f'REPLICAS: {REPLICAS}')
    
    return strategy, REPLICAS, IS_TPU

STRATEGY, N_REPLICAS, IS_TPU = get_strategy()
# Out:
# connecting to TPU...
# REPLICAS: 8

# %%
#NOTE: you should run KaggleDatasets.get_gcs_path(dataset_name) in the kaggle notebook to update gcs_path as they expires after several weeks..
#notebook: https://www.kaggle.com/code/hoyso48/islr-get-gcs-path

GCS_PATH = {
            'ISLR':'gs://kds-07ef6b204aa5081e269a277f7fe8c8c1361ce30f6900d5d439a44074',
            '5fold':'gs://kds-b525bf8be78012d70e4e11b3fb9907d0bb2f265d748a7321c2d58f33',
            '5fold_randsplit':'gs://kds-06ac5cc1c0e92db27870f1acae71b8c815f2ce024d19bd0d354bd4a5',
            }

TRAIN_FILENAMES = tf.io.gfile.glob(GCS_PATH['5fold']+'/*.tfrecords')
COMPETITION_PATH = GCS_PATH['ISLR']

print(len(TRAIN_FILENAMES))
# !gsutil cp {COMPETITION_PATH}/train.csv .
# !gsutil cp {COMPETITION_PATH}/sign_to_prediction_index_map.json .
# Out:
# ['gs://kds-03513c26eb0c5ed5a75b8a416403ecd289ae2710647f5fb5b7d7fca0']
# 187
# Copying gs://kds-8810d6ee7ea1d6c85022ed2d1816dc67423f39111bc053a5fd8c7ddd/train.csv...
# / [1 files][  6.1 MiB/  6.1 MiB]
# Operation completed over 1 objects/6.1 MiB.
# Copying gs://kds-8810d6ee7ea1d6c85022ed2d1816dc67423f39111bc053a5fd8c7ddd/sign_to_prediction_index_map.json...
# / [1 files][  3.3 KiB/  3.3 KiB]
# Operation completed over 1 objects/3.3 KiB.

# %%
# Train DataFrame
train_df = pd.read_csv('train.csv')
display(train_df.head())
display(train_df.info())
# Out:
#                                             path  participant_id  sequence_id  \
# 0  train_landmark_files/26734/1000035562.parquet           26734   1000035562
# 1  train_landmark_files/28656/1000106739.parquet           28656   1000106739
# 2   train_landmark_files/16069/100015657.parquet           16069    100015657
# 3  train_landmark_files/25571/1000210073.parquet           25571   1000210073
# 4  train_landmark_files/62590/1000240708.parquet           62590   1000240708
#
#     sign
# 0   blow
# 1   wait
# 2  cloud
# 3   bird
# 4   owie
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94477 entries, 0 to 94476
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   path            94477 non-null  object
#  1   participant_id  94477 non-null  int64
#  2   sequence_id     94477 non-null  int64
#  3   sign            94477 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 2.9+ MB
# None

# %%
import re
def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename.split('/')[-1]).group(1)) for filename in filenames]
    return np.sum(n)
print(count_data_items(TRAIN_FILENAMES), len(train_df))
assert count_data_items(TRAIN_FILENAMES) == len(train_df)
# Out:
# 94477 94477

# %%
ROWS_PER_FRAME = 543
MAX_LEN = 384
CROP_LEN = MAX_LEN
NUM_CLASSES  = 250
PAD = -100.
NOSE=[
    1,2,98,327
]
LNOSE = [98]
RNOSE = [327]
LIP = [ 0, 
    61, 185, 40, 39, 37, 267, 269, 270, 409,
    291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
    78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
    95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
]
LLIP = [84,181,91,146,61,185,40,39,37,87,178,88,95,78,191,80,81,82]
RLIP = [314,405,321,375,291,409,270,269,267,317,402,318,324,308,415,310,311,312]

POSE = [500, 502, 504, 501, 503, 505, 512, 513]
LPOSE = [513,505,503,501]
RPOSE = [512,504,502,500]

REYE = [
    33, 7, 163, 144, 145, 153, 154, 155, 133,
    246, 161, 160, 159, 158, 157, 173,
]
LEYE = [
    263, 249, 390, 373, 374, 380, 381, 382, 362,
    466, 388, 387, 386, 385, 384, 398,
]

LHAND = np.arange(468, 489).tolist()
RHAND = np.arange(522, 543).tolist()

POINT_LANDMARKS = LIP + LHAND + RHAND + NOSE + REYE + LEYE #+POSE

NUM_NODES = len(POINT_LANDMARKS)
CHANNELS = 6*NUM_NODES

print(NUM_NODES)
print(CHANNELS)

def interp1d_(x, target_len, method='random'):
    length = tf.shape(x)[1]
    target_len = tf.maximum(1,target_len)
    if method == 'random':
        if tf.random.uniform(()) < 0.33:
            x = tf.image.resize(x, (target_len,tf.shape(x)[1]),'bilinear')
        else:
            if tf.random.uniform(()) < 0.5:
                x = tf.image.resize(x, (target_len,tf.shape(x)[1]),'bicubic')
            else:
                x = tf.image.resize(x, (target_len,tf.shape(x)[1]),'nearest')
    else:
        x = tf.image.resize(x, (target_len,tf.shape(x)[1]),method)
    return x

def tf_nan_mean(x, axis=0, keepdims=False):
    return tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), x), axis=axis, keepdims=keepdims) / tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), tf.ones_like(x)), axis=axis, keepdims=keepdims)

def tf_nan_std(x, center=None, axis=0, keepdims=False):
    if center is None:
        center = tf_nan_mean(x, axis=axis,  keepdims=True)
    d = x - center
    return tf.math.sqrt(tf_nan_mean(d * d, axis=axis, keepdims=keepdims))

class Preprocess(tf.keras.layers.Layer):
    def __init__(self, max_len=MAX_LEN, point_landmarks=POINT_LANDMARKS, **kwargs):
        super().__init__(**kwargs)
        self.max_len = max_len
        self.point_landmarks = point_landmarks

    def call(self, inputs):
        if tf.rank(inputs) == 3:
            x = inputs[None,...]
        else:
            x = inputs
        
        mean = tf_nan_mean(tf.gather(x, [17], axis=2), axis=[1,2], keepdims=True)
        mean = tf.where(tf.math.is_nan(mean), tf.constant(0.5,x.dtype), mean)
        x = tf.gather(x, self.point_landmarks, axis=2) #N,T,P,C
        std = tf_nan_std(x, center=mean, axis=[1,2], keepdims=True)
        
        x = (x - mean)/std

        if self.max_len is not None:
            x = x[:,:self.max_len]
        length = tf.shape(x)[1]
        x = x[...,:2]

        dx = tf.cond(tf.shape(x)[1]>1,lambda:tf.pad(x[:,1:] - x[:,:-1], [[0,0],[0,1],[0,0],[0,0]]),lambda:tf.zeros_like(x))

        dx2 = tf.cond(tf.shape(x)[1]>2,lambda:tf.pad(x[:,2:] - x[:,:-2], [[0,0],[0,2],[0,0],[0,0]]),lambda:tf.zeros_like(x))

        x = tf.concat([
            tf.reshape(x, (-1,length,2*len(self.point_landmarks))),
            tf.reshape(dx, (-1,length,2*len(self.point_landmarks))),
            tf.reshape(dx2, (-1,length,2*len(self.point_landmarks))),
        ], axis = -1)
        
        x = tf.where(tf.math.is_nan(x),tf.constant(0.,x.dtype),x)
        
        return x
# Out:
# 118
# 708

# %%
def decode_tfrec(record_bytes):
    features = tf.io.parse_single_example(record_bytes, {
        'coordinates': tf.io.FixedLenFeature([], tf.string),
        'sign': tf.io.FixedLenFeature([], tf.int64),
    })
    out = {}
    out['coordinates']  = tf.reshape(tf.io.decode_raw(features['coordinates'], tf.float32), (-1,ROWS_PER_FRAME,3))
    out['sign'] = features['sign']
    return out

def filter_nans_tf(x, ref_point=POINT_LANDMARKS):
    mask = tf.math.logical_not(tf.reduce_all(tf.math.is_nan(tf.gather(x,ref_point,axis=1)), axis=[-2,-1]))
    x = tf.boolean_mask(x, mask, axis=0)
    return x

def preprocess(x, augment=False, max_len=MAX_LEN):
    coord = x['coordinates']
    coord = filter_nans_tf(coord)
    if augment:
        coord = augment_fn(coord, max_len=max_len)
    coord = tf.ensure_shape(coord, (None,ROWS_PER_FRAME,3))
    
    return tf.cast(Preprocess(max_len=max_len)(coord)[0],tf.float32), tf.one_hot(x['sign'], NUM_CLASSES)

def flip_lr(x):
    x,y,z = tf.unstack(x, axis=-1)
    x = 1-x
    new_x = tf.stack([x,y,z], -1)
    new_x = tf.transpose(new_x, [1,0,2])
    lhand = tf.gather(new_x, LHAND, axis=0)
    rhand = tf.gather(new_x, RHAND, axis=0)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(LHAND)[...,None], rhand)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(RHAND)[...,None], lhand)
    llip = tf.gather(new_x, LLIP, axis=0)
    rlip = tf.gather(new_x, RLIP, axis=0)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(LLIP)[...,None], rlip)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(RLIP)[...,None], llip)
    lpose = tf.gather(new_x, LPOSE, axis=0)
    rpose = tf.gather(new_x, RPOSE, axis=0)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(LPOSE)[...,None], rpose)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(RPOSE)[...,None], lpose)
    leye = tf.gather(new_x, LEYE, axis=0)
    reye = tf.gather(new_x, REYE, axis=0)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(LEYE)[...,None], reye)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(REYE)[...,None], leye)
    lnose = tf.gather(new_x, LNOSE, axis=0)
    rnose = tf.gather(new_x, RNOSE, axis=0)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(LNOSE)[...,None], rnose)
    new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(RNOSE)[...,None], lnose)
    new_x = tf.transpose(new_x, [1,0,2])
    return new_x

def resample(x, rate=(0.8,1.2)):
    rate = tf.random.uniform((), rate[0], rate[1])
    length = tf.shape(x)[0]
    new_size = tf.cast(rate*tf.cast(length,tf.float32), tf.int32) #(tf.cast(rate*tf.cast(length,tf.float32), tf.int32),tf.shape(x)[1])
    new_x = interp1d_(x, new_size) #tf.image.resize(x, new_size, method='bilinear')
    return new_x

def spatial_random_affine(xyz,
    scale  = (0.8,1.2),
    shear = (-0.15,0.15),
    shift  = (-0.1,0.1),
    degree = (-30,30),
):
    center = tf.constant([0.5,0.5])
    if scale is not None:
        scale = tf.random.uniform((),*scale)
        xyz = scale*xyz

    if shear is not None:
        xy = xyz[...,:2]
        z = xyz[...,2:]
        shear_x = shear_y = tf.random.uniform((),*shear)
        if tf.random.uniform(()) < 0.5:
            shear_x = 0.
        else:
            shear_y = 0.
        shear_mat = tf.identity([
            [1.,shear_x],
            [shear_y,1.]
        ])
        xy = xy @ shear_mat
        center = center + [shear_y, shear_x]
        xyz = tf.concat([xy,z], axis=-1)

    if degree is not None:
        xy = xyz[...,:2]
        z = xyz[...,2:]
        xy -= center
        degree = tf.random.uniform((),*degree)
        radian = degree/180*np.pi
        c = tf.math.cos(radian)
        s = tf.math.sin(radian)
        rotate_mat = tf.identity([
            [c,s],
            [-s, c],
        ])
        xy = xy @ rotate_mat
        xy = xy + center
        xyz = tf.concat([xy,z], axis=-1)

    if shift is not None:
        shift = tf.random.uniform((),*shift)
        xyz = xyz + shift

    return xyz

def temporal_crop(x, length=MAX_LEN):
    l = tf.shape(x)[0]
    offset = tf.random.uniform((), 0, tf.clip_by_value(l-length,1,length), dtype=tf.int32)
    x = x[offset:offset+length]
    return x

def temporal_mask(x, size=(0.2,0.4), mask_value=float('nan')):
    l = tf.shape(x)[0]
    mask_size = tf.random.uniform((), *size)
    mask_size = tf.cast(tf.cast(l, tf.float32) * mask_size, tf.int32)
    mask_offset = tf.random.uniform((), 0, tf.clip_by_value(l-mask_size,1,l), dtype=tf.int32)
    x = tf.tensor_scatter_nd_update(x,tf.range(mask_offset, mask_offset+mask_size)[...,None],tf.fill([mask_size,543,3],mask_value))
    return x

def spatial_mask(x, size=(0.2,0.4), mask_value=float('nan')):
    mask_offset_y = tf.random.uniform(())
    mask_offset_x = tf.random.uniform(())
    mask_size = tf.random.uniform((), *size)
    mask_x = (mask_offset_x<x[...,0]) & (x[...,0] < mask_offset_x + mask_size)
    mask_y = (mask_offset_y<x[...,1]) & (x[...,1] < mask_offset_y + mask_size)
    mask = mask_x & mask_y
    x = tf.where(mask[...,None], mask_value, x)
    return x

def augment_fn(x, always=False, max_len=None):
    if tf.random.uniform(())<0.8 or always:
        x = resample(x, (0.5,1.5))
    if tf.random.uniform(())<0.5 or always:
        x = flip_lr(x)
    if max_len is not None:
        x = temporal_crop(x, max_len)
    if tf.random.uniform(())<0.75 or always:
        x = spatial_random_affine(x)
    if tf.random.uniform(())<0.5 or always:
        x = temporal_mask(x)
    if tf.random.uniform(())<0.5 or always:
        x = spatial_mask(x)
    return x

def get_tfrec_dataset(tfrecords, batch_size=64, max_len=64, drop_remainder=False, augment=False, shuffle=False, repeat=False):
    # Initialize dataset with TFRecords
    ds = tf.data.TFRecordDataset(tfrecords, num_parallel_reads=tf.data.AUTOTUNE, compression_type='GZIP')
    ds = ds.map(decode_tfrec, tf.data.AUTOTUNE)
    ds = ds.map(lambda x: preprocess(x, augment=augment, max_len=max_len), tf.data.AUTOTUNE)

    if repeat: 
        ds = ds.repeat()
        
    if shuffle:
        ds = ds.shuffle(shuffle)
        options = tf.data.Options()
        options.experimental_deterministic = (False)
        ds = ds.with_options(options)
    
    if batch_size:
        ds = ds.padded_batch(batch_size, padding_values=PAD, padded_shapes=([max_len,CHANNELS],[NUM_CLASSES]), drop_remainder=drop_remainder)

    ds = ds.prefetch(tf.data.AUTOTUNE)
        
    return ds

ds = get_tfrec_dataset(TRAIN_FILENAMES, augment=True, batch_size=1024)
for x in ds:
    temp_train = x
    break

# %%
from IPython.display import HTML
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation

def filter_nans(frames):
    return frames[~np.isnan(frames).all(axis=(-2,-1))]

ds = tf.data.TFRecordDataset(TRAIN_FILENAMES, num_parallel_reads=tf.data.AUTOTUNE, compression_type='GZIP')
ds = ds.map(decode_tfrec, tf.data.AUTOTUNE)
print(ds)
for x in ds:
    temp = x['coordinates'].numpy()
    if not len(filter_nans(temp[:,LHAND])) == 0:
        break
    
edges = [(0,1),(1,2),(2,3),(3,4),(0,5),(0,17),(5,6),(6,7),(7,8),(5,9),(9,10),(10,11),(11,12),
         (9,13),(13,14),(14,15),(15,16),(13,17),(17,18),(18,19),(19,20)]

fig, ax = plt.subplots()

def plot_frame(frame, edges=[], idxs=[]):
        
    frame[np.isnan(frame)] = 0
    x = list(frame[...,0])
    y = list(frame[...,1])
    if len(idxs) == 0:
        idxs = list(range(len(x)))
    ax.clear()
    ax.scatter(x, y, color='dodgerblue')
    for i in range(len(x)):
        ax.text(x[i], y[i], idxs[i])
        
    for edge in edges:
        ax.plot([x[edge[0]], x[edge[1]]], [y[edge[0]], y[edge[1]]], color='salmon')
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xticklabels([])
    ax.set_yticklabels([])

def animate_frames(frames, edges=[], idxs=[]):
    anim = FuncAnimation(fig, lambda frame: plot_frame(frame, edges, idxs), frames=frames, interval=100)
    return HTML(anim.to_jshtml())
# Out:
# <_ParallelMapDataset element_spec={'coordinates': TensorSpec(shape=(None, 543, 3), dtype=tf.float32, name=None), 'sign': TensorSpec(shape=(), dtype=tf.int64, name=None)}>

# %%
# Animate the frames
animate_frames(filter_nans(temp[:,LHAND]),edges=edges)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgdb91f7254dee42cc86033cbc67f9f8cc">
#   <div class="anim-controls">
#     <input id="_anim_sliderdb91f7254dee42cc86033cbc67f9f8cc" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animdb91f7254dee42cc86033cbc67f9f8cc.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animdb91f7254dee42cc86033cbc67f9f8cc.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectdb91f7254dee42cc86033cbc67f9f8cc"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_db91f7254dee42cc86033cbc67f9f8cc"
#              >
#       <label for="_anim_radio1_db91f7254dee42cc86033cbc67f9f8cc">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_db91f7254dee42cc86033cbc67f9f8cc"
#              checked>
#       <label for="_anim_radio2_db91f7254dee42cc86033cbc67f9f8cc">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_db91f7254dee42cc86033cbc67f9f8cc"
#              >
#       <label for="_anim_radio3_db91f7254dee42cc86033cbc67f9f8cc">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdb91f7254dee42cc86033cbc67f9f8cc";
#     var slider_id = "_anim_sliderdb91f7254dee42cc86033cbc67f9f8cc";
#     var loop_select_id = "_anim_loop_selectdb91f7254dee42cc86033cbc67f9f8cc";
#     var frames = new Array(1);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABjTUlEQV

# %%
animate_frames(filter_nans(augment_fn(temp,always=True).numpy()[:,RHAND]),edges=edges)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgab207d568a0f4766abb4b2048bcdadbe">
#   <div class="anim-controls">
#     <input id="_anim_sliderab207d568a0f4766abb4b2048bcdadbe" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animab207d568a0f4766abb4b2048bcdadbe.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animab207d568a0f4766abb4b2048bcdadbe.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animab207d568a0f4766abb4b2048bcdadbe.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animab207d568a0f4766abb4b2048bcdadbe.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animab207d568a0f4766abb4b2048bcdadbe.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animab207d568a0f4766abb4b2048bcdadbe.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animab207d568a0f4766abb4b2048bcdadbe.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animab207d568a0f4766abb4b2048bcdadbe.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animab207d568a0f4766abb4b2048bcdadbe.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animab207d568a0f4766abb4b2048bcdadbe.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectab207d568a0f4766abb4b2048bcdadbe"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_ab207d568a0f4766abb4b2048bcdadbe"
#              >
#       <label for="_anim_radio1_ab207d568a0f4766abb4b2048bcdadbe">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_ab207d568a0f4766abb4b2048bcdadbe"
#              checked>
#       <label for="_anim_radio2_ab207d568a0f4766abb4b2048bcdadbe">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_ab207d568a0f4766abb4b2048bcdadbe"
#              >
#       <label for="_anim_radio3_ab207d568a0f4766abb4b2048bcdadbe">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgab207d568a0f4766abb4b2048bcdadbe";
#     var slider_id = "_anim_sliderab207d568a0f4766abb4b2048bcdadbe";
#     var loop_select_id = "_anim_loop_selectab207d568a0f4766abb4b2048bcdadbe";
#     var frames = new Array(1);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABvYUlEQV

# %%
animate_frames(filter_nans(temp[:,POINT_LANDMARKS]))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgd16b4055940b497caf73bc936fc8b1a5">
#   <div class="anim-controls">
#     <input id="_anim_sliderd16b4055940b497caf73bc936fc8b1a5" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animd16b4055940b497caf73bc936fc8b1a5.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animd16b4055940b497caf73bc936fc8b1a5.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animd16b4055940b497caf73bc936fc8b1a5.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animd16b4055940b497caf73bc936fc8b1a5.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animd16b4055940b497caf73bc936fc8b1a5.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animd16b4055940b497caf73bc936fc8b1a5.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animd16b4055940b497caf73bc936fc8b1a5.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animd16b4055940b497caf73bc936fc8b1a5.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animd16b4055940b497caf73bc936fc8b1a5.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animd16b4055940b497caf73bc936fc8b1a5.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectd16b4055940b497caf73bc936fc8b1a5"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_d16b4055940b497caf73bc936fc8b1a5"
#              >
#       <label for="_anim_radio1_d16b4055940b497caf73bc936fc8b1a5">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_d16b4055940b497caf73bc936fc8b1a5"
#              checked>
#       <label for="_anim_radio2_d16b4055940b497caf73bc936fc8b1a5">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_d16b4055940b497caf73bc936fc8b1a5"
#              >
#       <label for="_anim_radio3_d16b4055940b497caf73bc936fc8b1a5">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd16b4055940b497caf73bc936fc8b1a5";
#     var slider_id = "_anim_sliderd16b4055940b497caf73bc936fc8b1a5";
#     var loop_select_id = "_anim_loop_selectd16b4055940b497caf73bc936fc8b1a5";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABLLklEQV

# %%
animate_frames(filter_nans(augment_fn(temp,always=True).numpy()[:,POINT_LANDMARKS]), idxs=POINT_LANDMARKS)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img2d4072b32fbc403dbe9d94594243fcff">
#   <div class="anim-controls">
#     <input id="_anim_slider2d4072b32fbc403dbe9d94594243fcff" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim2d4072b32fbc403dbe9d94594243fcff.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim2d4072b32fbc403dbe9d94594243fcff.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim2d4072b32fbc403dbe9d94594243fcff.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim2d4072b32fbc403dbe9d94594243fcff.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim2d4072b32fbc403dbe9d94594243fcff.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim2d4072b32fbc403dbe9d94594243fcff.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim2d4072b32fbc403dbe9d94594243fcff.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim2d4072b32fbc403dbe9d94594243fcff.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim2d4072b32fbc403dbe9d94594243fcff.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim2d4072b32fbc403dbe9d94594243fcff.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select2d4072b32fbc403dbe9d94594243fcff"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_2d4072b32fbc403dbe9d94594243fcff"
#              >
#       <label for="_anim_radio1_2d4072b32fbc403dbe9d94594243fcff">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_2d4072b32fbc403dbe9d94594243fcff"
#              checked>
#       <label for="_anim_radio2_2d4072b32fbc403dbe9d94594243fcff">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_2d4072b32fbc403dbe9d94594243fcff"
#              >
#       <label for="_anim_radio3_2d4072b32fbc403dbe9d94594243fcff">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img2d4072b32fbc403dbe9d94594243fcff";
#     var slider_id = "_anim_slider2d4072b32fbc403dbe9d94594243fcff";
#     var loop_select_id = "_anim_loop_select2d4072b32fbc403dbe9d94594243fcff";
#     var frames = new Array(3);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/bCgiHAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABYGUlEQV

# %%
class ECA(tf.keras.layers.Layer):
    def __init__(self, gamma=2.0, beta=1.0, **kwargs):
        super().__init__(**kwargs)
        self.supports_masking = True
        self.conv = None
        self.gamma = gamma
        self.beta = beta
    
    def build(self, input_shape):
        filters = input_shape[-1]
        beta, gamma = float(self.beta), float(self.gamma)
        tt = int((np.log(float(filters)) / np.log(2.0) + beta) / gamma)
        kernel_size = max(tt if tt % 2 else tt + 1, 3)
        self.conv = tf.keras.layers.Conv1D(1, kernel_size=kernel_size, strides=1, padding="same", use_bias=False)
        super().build(input_shape)

    def call(self, inputs, mask=None):
        nn = tf.keras.layers.GlobalAveragePooling1D()(inputs, mask=mask)
        nn = tf.expand_dims(nn, -1)
        nn = self.conv(nn)
        nn = tf.squeeze(nn, -1)
        nn = tf.nn.sigmoid(nn)
        nn = nn[:,None,:]
        return inputs * nn

class LateDropout(tf.keras.layers.Layer):
    def __init__(self, rate, noise_shape=None, start_step=0, **kwargs):
        super().__init__(**kwargs)
        self.supports_masking = True
        self.rate = rate
        self.start_step = start_step
        self.dropout = tf.keras.layers.Dropout(rate, noise_shape=noise_shape)
      
    def build(self, input_shape):
        super().build(input_shape)
        agg = tf.VariableAggregation.ONLY_FIRST_REPLICA
        self._train_counter = tf.Variable(0, dtype="int64", aggregation=agg, trainable=False)

    def call(self, inputs, training=False):
        x = tf.cond(self._train_counter < self.start_step, lambda:inputs, lambda:self.dropout(inputs, training=training))
        if training:
          self._train_counter.assign_add(1)
        return x

class CausalDWConv1D(tf.keras.layers.Layer):
    def __init__(self, 
        kernel_size=17,
        dilation_rate=1,
        use_bias=False,
        depthwise_initializer='glorot_uniform',
        name='', **kwargs):
        super().__init__(name=name,**kwargs)
        self.causal_pad = tf.keras.layers.ZeroPadding1D((dilation_rate*(kernel_size-1),0),name=name + '_pad')
        self.dw_conv = tf.keras.layers.DepthwiseConv1D(
                            kernel_size,
                            strides=1,
                            dilation_rate=dilation_rate,
                            padding='valid',
                            use_bias=use_bias,
                            depthwise_initializer=depthwise_initializer,
                            name=name + '_dwconv')
        self.supports_masking = True
        
    def call(self, inputs):
        x = self.causal_pad(inputs)
        x = self.dw_conv(x)
        return x

def Conv1DBlock(channel_size,
          kernel_size,
          dilation_rate=1,
          drop_rate=0.0,
          expand_ratio=2,
          se_ratio=0.25,
          activation='swish',
          name=None):
  if name is None:
    name = str(tf.keras.backend.get_uid("mbblock"))
  # Expansion phase
  def apply(inputs):
    channels_in = tf.keras.backend.int_shape(inputs)[-1]
    channels_expand = channels_in * expand_ratio
    
    skip = inputs

    x = tf.keras.layers.Dense(
        channels_expand,
        use_bias=True,
        activation=activation,
        name=name + '_expand_conv')(inputs)

    # Depthwise Convolution
    x = CausalDWConv1D(kernel_size,
        dilation_rate=dilation_rate,
        use_bias=False,
        name=name + '_dwconv')(x)
    
    x = tf.keras.layers.BatchNormalization(momentum=0.95, name=name + '_bn')(x)

    x  = ECA()(x)

    x = tf.keras.layers.Dense(
        channel_size,
        use_bias=True,
        name=name + '_project_conv')(x)

    if drop_rate > 0:
        x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1), name=name + '_drop')(x)
    
    if (channels_in == channel_size):
        x = tf.keras.layers.add([x, skip], name=name + '_add')
    return x

  return apply

# %%
class MultiHeadSelfAttention(tf.keras.layers.Layer):
    def __init__(self, dim=256, num_heads=4, dropout=0, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.scale = self.dim ** -0.5
        self.num_heads = num_heads
        self.qkv = tf.keras.layers.Dense(3 * dim, use_bias=False)
        self.drop1 = tf.keras.layers.Dropout(dropout)
        self.proj = tf.keras.layers.Dense(dim, use_bias=False)
        self.supports_masking = True

    def call(self, inputs, mask=None):
        qkv = self.qkv(inputs)
        qkv = tf.keras.layers.Permute((2, 1, 3))(tf.keras.layers.Reshape((-1, self.num_heads, self.dim * 3 // self.num_heads))(qkv))
        q, k, v = tf.split(qkv, [self.dim // self.num_heads] * 3, axis=-1)

        attn = tf.matmul(q, k, transpose_b=True) * self.scale

        if mask is not None:
            mask = mask[:, None, None, :]

        attn = tf.keras.layers.Softmax(axis=-1)(attn, mask=mask)
        attn = self.drop1(attn)

        x = attn @ v
        x = tf.keras.layers.Reshape((-1, self.dim))(tf.keras.layers.Permute((2, 1, 3))(x))
        x = self.proj(x)
        return x

def TransformerBlock(dim=256, num_heads=4, expand=4, attn_dropout=0.2, drop_rate=0.2, activation='swish'):
    def apply(inputs):
        x = inputs
        x = tf.keras.layers.BatchNormalization(momentum=0.95)(x)
        x = MultiHeadSelfAttention(dim=dim,num_heads=num_heads,dropout=attn_dropout)(x)
        x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1))(x)
        x = tf.keras.layers.Add()([inputs, x])
        attn_out = x

        x = tf.keras.layers.BatchNormalization(momentum=0.95)(x)
        x = tf.keras.layers.Dense(dim*expand, use_bias=False, activation=activation)(x)
        x = tf.keras.layers.Dense(dim, use_bias=False)(x)
        x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1))(x)
        x = tf.keras.layers.Add()([attn_out, x])
        return x
    return apply

# %%
def get_model(max_len=64, dropout_step=0, dim=192):
    inp = tf.keras.Input((max_len,CHANNELS))
    x = tf.keras.layers.Masking(mask_value=PAD,input_shape=(max_len,CHANNELS))(inp)
    ksize = 17
    x = tf.keras.layers.Dense(dim, use_bias=False,name='stem_conv')(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.95,name='stem_bn')(x)

    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = TransformerBlock(dim,expand=2)(x)

    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
    x = TransformerBlock(dim,expand=2)(x)

    if dim == 384: #for the 4x sized model
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = TransformerBlock(dim,expand=2)(x)

        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=0.2)(x)
        x = TransformerBlock(dim,expand=2)(x)

    x = tf.keras.layers.Dense(dim*2,activation=None,name='top_conv')(x)
    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = LateDropout(0.8, start_step=dropout_step)(x)
    x = tf.keras.layers.Dense(NUM_CLASSES,name='classifier')(x)
    return tf.keras.Model(inp, x)

model = get_model()
y = model(temp_train[0])
tf.keras.losses.CategoricalCrossentropy(from_logits=True)(temp_train[1],y)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=5.757965>

# %%
#check supports_masking
for x in model.layers:
    if not x.supports_masking:
        print(x.supports_masking, x.name)

# %%
def train_fold(CFG, fold, train_files, valid_files=None, strategy=STRATEGY, summary=True):
    seed_everything(CFG.seed)
    tf.keras.backend.clear_session()
    gc.collect()
    tf.config.optimizer.set_jit(True)
        
    if CFG.fp16:
        try:
            policy = mixed_precision.Policy('mixed_bfloat16')
            mixed_precision.set_global_policy(policy)
        except:
            policy = mixed_precision.Policy('mixed_float16')
            mixed_precision.set_global_policy(policy)
    else:
        policy = mixed_precision.Policy('float32')
        mixed_precision.set_global_policy(policy)

    if fold != 'all':
        train_ds = get_tfrec_dataset(train_files, batch_size=CFG.batch_size, max_len=CFG.max_len, drop_remainder=True, augment=True, repeat=True, shuffle=32768)
        valid_ds = get_tfrec_dataset(valid_files, batch_size=CFG.batch_size, max_len=CFG.max_len, drop_remainder=False, repeat=False, shuffle=False)
    else:
        train_ds = get_tfrec_dataset(train_files, batch_size=CFG.batch_size, max_len=CFG.max_len, drop_remainder=False, augment=True, repeat=True, shuffle=32768)
        valid_ds = None
        valid_files = []
    
    num_train = count_data_items(train_files)
    num_valid = count_data_items(valid_files)
    steps_per_epoch = num_train//CFG.batch_size
    with strategy.scope():
        dropout_step = CFG.dropout_start_epoch * steps_per_epoch
        model = get_model(max_len=CFG.max_len, dropout_step=dropout_step, dim=CFG.dim)

        schedule = OneCycleLR(CFG.lr, CFG.epoch, warmup_epochs=CFG.epoch*CFG.warmup, steps_per_epoch=steps_per_epoch, resume_epoch=CFG.resume, decay_epochs=CFG.epoch, lr_min=CFG.lr_min, decay_type=CFG.decay_type, warmup_type='linear')
        decay_schedule = OneCycleLR(CFG.lr*CFG.weight_decay, CFG.epoch, warmup_epochs=CFG.epoch*CFG.warmup, steps_per_epoch=steps_per_epoch, resume_epoch=CFG.resume, decay_epochs=CFG.epoch, lr_min=CFG.lr_min*CFG.weight_decay, decay_type=CFG.decay_type, warmup_type='linear')
                
        awp_step = CFG.awp_start_epoch * steps_per_epoch
        if CFG.fgm:
            model = FGM(model.input, model.output, delta=CFG.awp_lambda, eps=0., start_step=awp_step)
        elif CFG.awp:
            model = AWP(model.input, model.output, delta=CFG.awp_lambda, eps=0., start_step=awp_step)

        opt = tfa.optimizers.RectifiedAdam(learning_rate=schedule, weight_decay=decay_schedule, sma_threshold=4)#, clipvalue=1.)
        opt = tfa.optimizers.Lookahead(opt,sync_period=5)

        model.compile(
            optimizer=opt,
            loss=[tf.keras.losses.CategoricalCrossentropy(from_logits=True,label_smoothing=0.1)],# [tf.keras.losses.CategoricalCrossentropy(from_logits=True)]
            metrics=[
                [
                tf.keras.metrics.CategoricalAccuracy(),
                ],
            ],
            steps_per_execution=steps_per_epoch,
        )
    
    if summary:
        print()
        model.summary()
        print()
        print(train_ds, valid_ds)
        print()
        schedule.plot()
        print()
        init=False
    print(f'---------fold{fold}---------')
    print(f'train:{num_train} valid:{num_valid}')
    print()
    
    if CFG.resume:
        print(f'resume from epoch{CFG.resume}')
        model.load_weights(f'{CFG.output_dir}/{CFG.comment}-fold{fold}-last.h5')
        if train_ds is not None:
            model.evaluate(train_ds.take(steps_per_epoch))
        if valid_ds is not None:
            model.evaluate(valid_ds)

    logger = tf.keras.callbacks.CSVLogger(f'{CFG.output_dir}/{CFG.comment}-fold{fold}-logs.csv')
    sv_loss = tf.keras.callbacks.ModelCheckpoint(f'{CFG.output_dir}/{CFG.comment}-fold{fold}-best.h5', monitor='val_loss', verbose=0, save_best_only=True,
                save_weights_only=True, mode='min', save_freq='epoch')
    snap = Snapshot(f'{CFG.output_dir}/{CFG.comment}-fold{fold}', CFG.snapshot_epochs)
    swa = SWA(f'{CFG.output_dir}/{CFG.comment}-fold{fold}', CFG.swa_epochs, strategy=strategy, train_ds=train_ds, valid_ds=valid_ds, valid_steps=-(num_valid//-CFG.batch_size))
    callbacks = []
    if CFG.save_output:
        callbacks.append(logger)
        callbacks.append(snap)
        callbacks.append(swa)
        if fold != 'all':
            callbacks.append(sv_loss)
        
    history = model.fit(
        train_ds,
        epochs=CFG.epoch-CFG.resume,
        steps_per_epoch=steps_per_epoch,
        callbacks=callbacks,
        validation_data=valid_ds,
        verbose=CFG.verbose,
        validation_steps=-(num_valid//-CFG.batch_size)
    )

    if CFG.save_output:
        try:
            model.load_weights(f'{CFG.output_dir}/{CFG.comment}-fold{fold}-best.h5')
        except:
            pass
    if fold != 'all':
        cv = model.evaluate(valid_ds,verbose=CFG.verbose,steps=-(num_valid//-CFG.batch_size))
    else:
        cv = None

    return model, cv, history

def train_folds(CFG, folds, strategy=STRATEGY, summary=True):
    for fold in folds:
        if fold != 'all':
            all_files = TRAIN_FILENAMES
            train_files = [x for x in all_files if f'fold{fold}' not in x]
            valid_files = [x for x in all_files if f'fold{fold}' in x]
        else:
            train_files = TRAIN_FILENAMES
            valid_files = None
        
        train_fold(CFG, fold, train_files, valid_files, strategy=strategy, summary=summary)
    return

# %%
class CFG:
    n_splits = 5
    save_output = True
    output_dir = '.'
    
    seed = 42
    verbose = 2 #0) silent 1) progress bar 2) one line per epoch
    
    max_len = 384
    replicas = 8
    lr = 5e-4 * replicas
    weight_decay = 0.1
    lr_min = 1e-6
    epoch = 300 #400
    warmup = 0
    batch_size = 64 * replicas
    snapshot_epochs = []
    swa_epochs = [] #list(range(epoch//2,epoch+1))
    
    fp16 = True
    fgm = False
    awp = True
    awp_lambda = 0.2
    awp_start_epoch = 15
    dropout_start_epoch = 15
    resume = 0
    decay_type = 'cosine'
    dim = 192
    comment = f'islr-fp16-192-8-seed{seed}'

# %%
train_folds(CFG, [0])

# %%
# CFG.seed = 42
# CFG.comment = f'islr-fp16-192-8-seed{CFG.seed}'
# train_folds(CFG, ['all'], summary=False)
# Out:
# ---------foldall---------
# train:94477 valid:0.0
#
# Epoch 1/300
# 184/184 - 393s - loss: 4.8435 - categorical_accuracy: 0.0983 - 393s/epoch - 2s/step
# Epoch 2/300
# 184/184 - 35s - loss: 3.8312 - categorical_accuracy: 0.2723 - 35s/epoch - 190ms/step
# Epoch 3/300
# 184/184 - 39s - loss: 3.3767 - categorical_accuracy: 0.3735 - 39s/epoch - 209ms/step
# Epoch 4/300
# 184/184 - 38s - loss: 3.0815 - categorical_accuracy: 0.4432 - 38s/epoch - 209ms/step
# Epoch 5/300
# 184/184 - 34s - loss: 2.8875 - categorical_accuracy: 0.4900 - 34s/epoch - 186ms/step
# Epoch 6/300
# 184/184 - 39s - loss: 2.7534 - categorical_accuracy: 0.5225 - 39s/epoch - 210ms/step
# Epoch 7/300
# 184/184 - 39s - loss: 2.6656 - categorical_accuracy: 0.5477 - 39s/epoch - 213ms/step
# Epoch 8/300
# 184/184 - 36s - loss: 2.5872 - categorical_accuracy: 0.5691 - 36s/epoch - 198ms/step
# Epoch 9/300
# 184/184 - 38s - loss: 2.5248 - categorical_accuracy: 0.5847 - 38s/epoch - 207ms/step
# Epoch 10/300
# 184/184 - 34s - loss: 2.4649 - categorical_accuracy: 0.5985 - 34s/epoch - 186ms/step
# Epoch 11/300
# 184/184 - 38s - loss: 2.4347 - categorical_accuracy: 0.6080 - 38s/epoch - 206ms/step
# Epoch 12/300
# 184/184 - 39s - loss: 2.3951 - categorical_accuracy: 0.6164 - 39s/epoch - 210ms/step
# Epoch 13/300
# 184/184 - 34s - loss: 2.3548 - categorical_accuracy: 0.6293 - 34s/epoch - 187ms/step
# Epoch 14/300
# 184/184 - 38s - loss: 2.3382 - categorical_accuracy: 0.6338 - 38s/epoch - 207ms/step
# Epoch 15/300
# 184/184 - 34s - loss: 2.3050 - categorical_accuracy: 0.6424 - 34s/epoch - 184ms/step
# Epoch 16/300
# 184/184 - 38s - loss: 3.8226 - categorical_accuracy: 0.2068 - 38s/epoch - 205ms/step
# Epoch 17/300
# 184/184 - 39s - loss: 3.4958 - categorical_accuracy: 0.2704 - 39s/epoch - 211ms/step
# Epoch 18/300
# 184/184 - 34s - loss: 3.3866 - categorical_accuracy: 0.2971 - 34s/epoch - 185ms/step
# Epoch 19/300
# 184/184 - 39s - loss: 3.3219 - categorical_accuracy: 0.3158 - 39s/epoch - 212ms/step
# Epoch 20/300
# 184/184 - 39s - loss: 3.2779 - categorical_accuracy: 0.3286 - 39s/epoch - 210ms/step
# Epoch 21/300
# 184/184 - 36s - loss: 3.2294 - categorical_accuracy: 0.3433 - 36s/epoch - 196ms/step
# Epoch 22/300
# 184/184 - 38s - loss: 3.2009 - categorical_accuracy: 0.3514 - 38s/epoch - 209ms/step
# Epoch 23/300
# 184/184 - 34s - loss: 3.1564 - categorical_accuracy: 0.3632 - 34s/epoch - 183ms/step
# Epoch 24/300
# 184/184 - 38s - loss: 3.1425 - categorical_accuracy: 0.3691 - 38s/epoch - 206ms/step
# Epoch 25/300
# 184/184 - 39s - loss: 3.1141 - categorical_accuracy: 0.3756 - 39s/epoch - 211ms/step
# Epoch 26/300
# 184/184 - 34s - loss: 3.0947 - categorical_accuracy: 0.3801 - 34s/epoch - 185ms/step
# Epoch 27/300
# 184/184 - 39s - loss: 3.0684 - categorical_accuracy: 0.3915 - 39s/epoch - 211ms/step
# Epoch 28/300
# 184/184 - 39s - loss: 3.0535 - categorical_accuracy: 0.3975 - 39s/epoch - 211ms/step
# Epoch 29/300
# 184/184 - 36s - loss: 3.0326 - categorical_accuracy: 0.4035 - 36s/epoch - 198ms/step
# Epoch 30/300
# 184/184 - 38s - loss: 3.0151 - categorical_accuracy: 0.4077 - 38s/epoch - 209ms/step
# Epoch 31/300
# 184/184 - 33s - loss: 2.9978 - categorical_accuracy: 0.4116 - 33s/epoch - 182ms/step
# Epoch 32/300
# 184/184 - 38s - loss: 2.9752 - categorical_accuracy: 0.4186 - 38s/epoch - 207ms/step
# Epoch 33/300
# 184/184 - 39s - loss: 2.9713 - categorical_accuracy: 0.4224 - 39s/epoch - 211ms/step
# Epoch 34/300
# 184/184 - 34s - loss: 2.9567 - categorical_accuracy: 0.4257 - 34s/epoch - 187ms/step
# Epoch 35/300
# 184/184 - 37s - loss: 2.9395 - categorical_accuracy: 0.4306 - 37s/epoch - 203ms/step
# Epoch 36/300
# 184/184 - 34s - loss: 2.9314 - categorical_accuracy: 0.4325 - 34s/epoch - 183ms/step
# Epoch 37/300
# 184/184 - 38s - loss: 2.9104 - categorical_accuracy: 0.4393 - 38s/epoch - 207ms/step
# Epoch 38/300
# 184/184 - 39s - loss: 2.8982 - categorical_accuracy: 0.4430 - 39s/epoch - 214ms/step
# Epoch 39/300
# 184/184 - 34s - loss: 2.8959 - categorical_accuracy: 0.4435 - 34s/epoch - 184ms/step
# Epoch 40/300
# 184/184 - 39s - loss: 2.8850 - categorical_accuracy: 0.4470 - 39s/epoch - 210ms/step
# Epoch 41/300
# 184/184 - 39s - loss: 2.8721 - categorical_accuracy: 0.4520 - 39s/epoch - 210ms/step
# Epoch 42/300
# 184/184 - 36s - loss: 2.8608 - categorical_accuracy: 0.4550 - 36s/epoch - 195ms/step
# Epoch 43/300
# 184/184 - 39s - loss: 2.8550 - categorical_accuracy: 0.4567 - 39s/epoch - 209ms/step
# Epoch 44/300
# 184/184 - 34s - loss: 2.8429 - categorical_accuracy: 0.4618 - 34s/epoch - 185ms/step
# Epoch 45/300
# 184/184 - 38s - loss: 2.8301 - categorical_accuracy: 0.4633 - 38s/epoch - 206ms/step
# Epoch 46/300
# 184/184 - 39s - loss: 2.8231 - categorical_accuracy: 0.4659 - 39s/epoch - 211ms/step
# Epoch 47/300
# 184/184 - 35s - loss: 2.8155 - categorical_accuracy: 0.4692 - 35s/epoch - 188ms/step
# Epoch 48/300
# 184/184 - 39s - loss: 2.8017 - categorical_accuracy: 0.4739 - 39s/epoch - 212ms/step
# Epoch 49/300
# 184/184 - 39s - loss: 2.7866 - categorical_accuracy: 0.4784 - 39s/epoch - 212ms/step
# Epoch 50/300
# 184/184 - 37s - loss: 2.7840 - categorical_accuracy: 0.4791 - 37s/epoch - 202ms/step
# Epoch 51/300
# 184/184 - 39s - loss: 2.7798 - categorical_accuracy: 0.4790 - 39s/epoch - 211ms/step
# Epoch 52/300
# 184/184 - 39s - loss: 2.7774 - categorical_accuracy: 0.4810 - 39s/epoch - 211ms/step
# Epoch 53/300
# 184/184 - 38s - loss: 2.7600 - categorical_accuracy: 0.4856 - 38s/epoch - 206ms/step
# Epoch 54/300
# 184/184 - 40s - loss: 2.7636 - categorical_accuracy: 0.4871 - 40s/epoch - 217ms/step
# Epoch 55/300
# 184/184 - 37s - loss: 2.7509 - categorical_accuracy: 0.4906 - 37s/epoch - 202ms/step
# Epoch 56/300
# 184/184 - 38s - loss: 2.7426 - categorical_accuracy: 0.4912 - 38s/epoch - 207ms/step
# Epoch 57/300
# 184/184 - 39s - loss: 2.7385 - categorical_accuracy: 0.4946 - 39s/epoch - 211ms/step
# Epoch 58/300
# 184/184 - 34s - loss: 2.7272 - categorical_accuracy: 0.4956 - 34s/epoch - 187ms/step
# Epoch 59/300
# 184/184 - 39s - loss: 2.7207 - categorical_accuracy: 0.4961 - 39s/epoch - 211ms/step
# Epoch 60/300
# 184/184 - 39s - loss: 2.7201 - categorical_accuracy: 0.5006 - 39s/epoch - 210ms/step
# Epoch 61/300
# 184/184 - 37s - loss: 2.7051 - categorical_accuracy: 0.5041 - 37s/epoch - 203ms/step
# Epoch 62/300
# 184/184 - 39s - loss: 2.7034 - categorical_accuracy: 0.5051 - 39s/epoch - 212ms/step
# Epoch 63/300
# 184/184 - 33s - loss: 2.6962 - categorical_accuracy: 0.5073 - 33s/epoch - 177ms/step
# Epoch 64/300
# 184/184 - 38s - loss: 2.6950 - categorical_accuracy: 0.5068 - 38s/epoch - 207ms/step
# Epoch 65/300
# 184/184 - 40s - loss: 2.6882 - categorical_accuracy: 0.5067 - 40s/epoch - 215ms/step
# Epoch 66/300
# 184/184 - 36s - loss: 2.6782 - categorical_accuracy: 0.5109 - 36s/epoch - 195ms/step
# Epoch 67/300
# 184/184 - 38s - loss: 2.6793 - categorical_accuracy: 0.5106 - 38s/epoch - 208ms/step
# Epoch 68/300
# 184/184 - 39s - loss: 2.6687 - categorical_accuracy: 0.5159 - 39s/epoch - 210ms/step
# Epoch 69/300
# 184/184 - 36s - loss: 2.6690 - categorical_accuracy: 0.5140 - 36s/epoch - 194ms/step
# Epoch 70/300
# 184/184 - 39s - loss: 2.6638 - categorical_accuracy: 0.5166 - 39s/epoch - 212ms/step
# Epoch 71/300
# 184/184 - 33s - loss: 2.6590 - categorical_accuracy: 0.5192 - 33s/epoch - 179ms/step
# Epoch 72/300
# 184/184 - 38s - loss: 2.6441 - categorical_accuracy: 0.5211 - 38s/epoch - 208ms/step
# Epoch 73/300
# 184/184 - 39s - loss: 2.6411 - categorical_accuracy: 0.5234 - 39s/epoch - 211ms/step
# Epoch 74/300
# 184/184 - 36s - loss: 2.6346 - categorical_accuracy: 0.5246 - 36s/epoch - 198ms/step
# Epoch 75/300
# 184/184 - 39s - loss: 2.6231 - categorical_accuracy: 0.5290 - 39s/epoch - 212ms/step
# Epoch 76/300
# 184/184 - 38s - loss: 2.6251 - categorical_accuracy: 0.5271 - 38s/epoch - 208ms/step
# Epoch 77/300
# 184/184 - 36s - loss: 2.6231 - categorical_accuracy: 0.5284 - 36s/epoch - 195ms/step
# Epoch 78/300
# 184/184 - 39s - loss: 2.6193 - categorical_accuracy: 0.5289 - 39s/epoch - 211ms/step
# Epoch 79/300
# 184/184 - 33s - loss: 2.6091 - categorical_accuracy: 0.5328 - 33s/epoch - 180ms/step
# Epoch 80/300
# 184/184 - 38s - loss: 2.6109 - categorical_accuracy: 0.5346 - 38s/epoch - 206ms/step
# Epoch 81/300
# 184/184 - 39s - loss: 2.6025 - categorical_accuracy: 0.5331 - 39s/epoch - 213ms/step
# Epoch 82/300
# 184/184 - 35s - loss: 2.6028 - categorical_accuracy: 0.5351 - 35s/epoch - 192ms/step
# Epoch 83/300
# 184/184 - 40s - loss: 2.5893 - categorical_accuracy: 0.5378 - 40s/epoch - 216ms/step
# Epoch 84/300
# 184/184 - 45s - loss: 2.5932 - categorical_accuracy: 0.5374 - 45s/epoch - 242ms/step
# Epoch 85/300
# 184/184 - 35s - loss: 2.5902 - categorical_accuracy: 0.5377 - 35s/epoch - 193ms/step
# Epoch 86/300
# 184/184 - 66s - loss: 2.5848 - categorical_accuracy: 0.5396 - 66s/epoch - 358ms/step
# Epoch 87/300
# 184/184 - 58s - loss: 2.5772 - categorical_accuracy: 0.5443 - 58s/epoch - 317ms/step
# Epoch 88/300
# 184/184 - 38s - loss: 2.5727 - categorical_accuracy: 0.5450 - 38s/epoch - 209ms/step
# Epoch 89/300
# 184/184 - 39s - loss: 2.5732 - categorical_accuracy: 0.5448 - 39s/epoch - 212ms/step
# Epoch 90/300
# 184/184 - 35s - loss: 2.5659 - categorical_accuracy: 0.5451 - 35s/epoch - 191ms/step
# Epoch 91/300
# 184/184 - 39s - loss: 2.5612 - categorical_accuracy: 0.5484 - 39s/epoch - 212ms/step
# Epoch 92/300
# 184/184 - 33s - loss: 2.5564 - categorical_accuracy: 0.5504 - 33s/epoch - 178ms/step
# Epoch 93/300
# 184/184 - 38s - loss: 2.5565 - categorical_accuracy: 0.5491 - 38s/epoch - 207ms/step
# Epoch 94/300
# 184/184 - 39s - loss: 2.5448 - categorical_accuracy: 0.5530 - 39s/epoch - 210ms/step
# Epoch 95/300
# 184/184 - 36s - loss: 2.5402 - categorical_accuracy: 0.5548 - 36s/epoch - 195ms/step
# Epoch 96/300
# 184/184 - 38s - loss: 2.5416 - categorical_accuracy: 0.5519 - 38s/epoch - 209ms/step
# Epoch 97/300
# 184/184 - 39s - loss: 2.5359 - categorical_accuracy: 0.5555 - 39s/epoch - 211ms/step
# Epoch 98/300
# 184/184 - 36s - loss: 2.5370 - categorical_accuracy: 0.5552 - 36s/epoch - 195ms/step
# Epoch 99/300
# 184/184 - 40s - loss: 2.5278 - categorical_accuracy: 0.5569 - 40s/epoch - 218ms/step
# Epoch 100/300
# 184/184 - 33s - loss: 2.5254 - categorical_accuracy: 0.5587 - 33s/epoch - 177ms/step
# Epoch 101/300
# 184/184 - 38s - loss: 2.5144 - categorical_accuracy: 0.5618 - 38s/epoch - 204ms/step
# Epoch 102/300
# 184/184 - 39s - loss: 2.5167 - categorical_accuracy: 0.5627 - 39s/epoch - 212ms/step
# Epoch 103/300
# 184/184 - 36s - loss: 2.5125 - categorical_accuracy: 0.5625 - 36s/epoch - 193ms/step
# Epoch 104/300
# 184/184 - 39s - loss: 2.5072 - categorical_accuracy: 0.5643 - 39s/epoch - 213ms/step
# Epoch 105/300
# 184/184 - 39s - loss: 2.5097 - categorical_accuracy: 0.5641 - 39s/epoch - 211ms/step
# Epoch 106/300
# 184/184 - 36s - loss: 2.5067 - categorical_accuracy: 0.5635 - 36s/epoch - 196ms/step
# Epoch 107/300
# 184/184 - 39s - loss: 2.4975 - categorical_accuracy: 0.5677 - 39s/epoch - 210ms/step
# Epoch 108/300
# 184/184 - 37s - loss: 2.4952 - categorical_accuracy: 0.5655 - 37s/epoch - 204ms/step
# Epoch 109/300
# 184/184 - 37s - loss: 2.4917 - categorical_accuracy: 0.5668 - 37s/epoch - 203ms/step
# Epoch 110/300
# 184/184 - 39s - loss: 2.4917 - categorical_accuracy: 0.5677 - 39s/epoch - 211ms/step
# Epoch 111/300
# 184/184 - 35s - loss: 2.4887 - categorical_accuracy: 0.5675 - 35s/epoch - 190ms/step
# Epoch 112/300
# 184/184 - 39s - loss: 2.4705 - categorical_accuracy: 0.5744 - 39s/epoch - 210ms/step
# Epoch 113/300
# 184/184 - 39s - loss: 2.4819 - categorical_accuracy: 0.5726 - 39s/epoch - 209ms/step
# Epoch 114/300
# 184/184 - 36s - loss: 2.4806 - categorical_accuracy: 0.5704 - 36s/epoch - 198ms/step
# Epoch 115/300
# 184/184 - 39s - loss: 2.4719 - categorical_accuracy: 0.5755 - 39s/epoch - 211ms/step
# Epoch 116/300
# 184/184 - 33s - loss: 2.4662 - categorical_accuracy: 0.5766 - 33s/epoch - 180ms/step
# Epoch 117/300
# 184/184 - 37s - loss: 2.4662 - categorical_accuracy: 0.5759 - 37s/epoch - 201ms/step
# Epoch 118/300
# 184/184 - 38s - loss: 2.4650 - categorical_accuracy: 0.5757 - 38s/epoch - 209ms/step
# Epoch 119/300
# 184/184 - 35s - loss: 2.4564 - categorical_accuracy: 0.5785 - 35s/epoch - 188ms/step
# Epoch 120/300
# 184/184 - 38s - loss: 2.4632 - categorical_accuracy: 0.5774 - 38s/epoch - 209ms/step
# Epoch 121/300
# 184/184 - 39s - loss: 2.4472 - categorical_accuracy: 0.5828 - 39s/epoch - 210ms/step
# Epoch 122/300
# 184/184 - 36s - loss: 2.4464 - categorical_accuracy: 0.5806 - 36s/epoch - 197ms/step
# Epoch 123/300
# 184/184 - 39s - loss: 2.4478 - categorical_accuracy: 0.5792 - 39s/epoch - 214ms/step
# Epoch 124/300
# 184/184 - 33s - loss: 2.4425 - categorical_accuracy: 0.5831 - 33s/epoch - 180ms/step
# Epoch 125/300
# 184/184 - 37s - loss: 2.4457 - categorical_accuracy: 0.5824 - 37s/epoch - 203ms/step
# Epoch 126/300
# 184/184 - 39s - loss: 2.4362 - categorical_accuracy: 0.5846 - 39s/epoch - 214ms/step
# Epoch 127/300
# 184/184 - 36s - loss: 2.4343 - categorical_accuracy: 0.5838 - 36s/epoch - 195ms/step
# Epoch 128/300
# 184/184 - 38s - loss: 2.4252 - categorical_accuracy: 0.5871 - 38s/epoch - 206ms/step
# Epoch 129/300
# 184/184 - 33s - loss: 2.4277 - categorical_accuracy: 0.5877 - 33s/epoch - 179ms/step
# Epoch 130/300
# 184/184 - 38s - loss: 2.4165 - categorical_accuracy: 0.5896 - 38s/epoch - 208ms/step
# Epoch 131/300
# 184/184 - 38s - loss: 2.4142 - categorical_accuracy: 0.5901 - 38s/epoch - 207ms/step
# Epoch 132/300
# 184/184 - 36s - loss: 2.4172 - categorical_accuracy: 0.5903 - 36s/epoch - 193ms/step
# Epoch 133/300
# 184/184 - 39s - loss: 2.4161 - categorical_accuracy: 0.5904 - 39s/epoch - 211ms/step
# Epoch 134/300
# 184/184 - 39s - loss: 2.3974 - categorical_accuracy: 0.5965 - 39s/epoch - 210ms/step
# Epoch 135/300
# 184/184 - 37s - loss: 2.4072 - categorical_accuracy: 0.5938 - 37s/epoch - 200ms/step
# Epoch 136/300
# 184/184 - 38s - loss: 2.4048 - categorical_accuracy: 0.5930 - 38s/epoch - 209ms/step
# Epoch 137/300
# 184/184 - 41s - loss: 2.4023 - categorical_accuracy: 0.5950 - 41s/epoch - 225ms/step
# Epoch 138/300
# 184/184 - 37s - loss: 2.3958 - categorical_accuracy: 0.5960 - 37s/epoch - 203ms/step
# Epoch 139/300
# 184/184 - 38s - loss: 2.3979 - categorical_accuracy: 0.5947 - 38s/epoch - 208ms/step
# Epoch 140/300
# 184/184 - 34s - loss: 2.3903 - categorical_accuracy: 0.5991 - 34s/epoch - 183ms/step
# Epoch 141/300
# 184/184 - 38s - loss: 2.3807 - categorical_accuracy: 0.6000 - 38s/epoch - 204ms/step
# Epoch 142/300
# 184/184 - 38s - loss: 2.3859 - categorical_accuracy: 0.5999 - 38s/epoch - 208ms/step
# Epoch 143/300
# 184/184 - 36s - loss: 2.3923 - categorical_accuracy: 0.5960 - 36s/epoch - 196ms/step
# Epoch 144/300
# 184/184 - 39s - loss: 2.3815 - categorical_accuracy: 0.5995 - 39s/epoch - 212ms/step
# Epoch 145/300
# 184/184 - 39s - loss: 2.3826 - categorical_accuracy: 0.5997 - 39s/epoch - 210ms/step
# Epoch 146/300
# 184/184 - 37s - loss: 2.3724 - categorical_accuracy: 0.6019 - 37s/epoch - 199ms/step
# Epoch 147/300
# Epoch 148/300
# 184/184 - 51s - loss: 2.3691 - categorical_accuracy: 0.6028 - 51s/epoch - 278ms/step
# Epoch 149/300
# 184/184 - 37s - loss: 2.3695 - categorical_accuracy: 0.6040 - 37s/epoch - 202ms/step
# Epoch 150/300
# 184/184 - 39s - loss: 2.3579 - categorical_accuracy: 0.6074 - 39s/epoch - 211ms/step
# Epoch 151/300
# 184/184 - 38s - loss: 2.3628 - categorical_accuracy: 0.6057 - 38s/epoch - 207ms/step
# Epoch 152/300
# 184/184 - 37s - loss: 2.3633 - categorical_accuracy: 0.6044 - 37s/epoch - 200ms/step
# Epoch 153/300
# 184/184 - 39s - loss: 2.3506 - categorical_accuracy: 0.6088 - 39s/epoch - 212ms/step
# Epoch 154/300
# 184/184 - 33s - loss: 2.3540 - categorical_accuracy: 0.6068 - 33s/epoch - 181ms/step
# Epoch 155/300
# 184/184 - 37s - loss: 2.3425 - categorical_accuracy: 0.6102 - 37s/epoch - 202ms/step
# Epoch 156/300
# 184/184 - 39s - loss: 2.3469 - categorical_accuracy: 0.6096 - 39s/epoch - 211ms/step
# Epoch 157/300
# 184/184 - 36s - loss: 2.3420 - categorical_accuracy: 0.6123 - 36s/epoch - 196ms/step
# Epoch 158/300
# 184/184 - 38s - loss: 2.3358 - categorical_accuracy: 0.6135 - 38s/epoch - 206ms/step
# Epoch 159/300
# 184/184 - 39s - loss: 2.3340 - categorical_accuracy: 0.6147 - 39s/epoch - 210ms/step
# Epoch 160/300
# 184/184 - 37s - loss: 2.3266 - categorical_accuracy: 0.6162 - 37s/epoch - 202ms/step
# Epoch 161/300
# 184/184 - 38s - loss: 2.3214 - categorical_accuracy: 0.6155 - 38s/epoch - 205ms/step
# Epoch 162/300
# 184/184 - 35s - loss: 2.3333 - categorical_accuracy: 0.6140 - 35s/epoch - 189ms/step
# Epoch 163/300
# 184/184 - 38s - loss: 2.3239 - categorical_accuracy: 0.6171 - 38s/epoch - 204ms/step
# Epoch 164/300
# 184/184 - 38s - loss: 2.3264 - categorical_accuracy: 0.6164 - 38s/epoch - 206ms/step
# Epoch 165/300
# 184/184 - 36s - loss: 2.3165 - categorical_accuracy: 0.6184 - 36s/epoch - 197ms/step
# Epoch 166/300
# 184/184 - 38s - loss: 2.3242 - categorical_accuracy: 0.6163 - 38s/epoch - 206ms/step
# Epoch 167/300
# 184/184 - 38s - loss: 2.3144 - categorical_accuracy: 0.6193 - 38s/epoch - 208ms/step
# Epoch 168/300
# 184/184 - 37s - loss: 2.3120 - categorical_accuracy: 0.6202 - 37s/epoch - 201ms/step
# Epoch 169/300
# 184/184 - 38s - loss: 2.3126 - categorical_accuracy: 0.6209 - 38s/epoch - 207ms/step
# Epoch 170/300
# 184/184 - 36s - loss: 2.3098 - categorical_accuracy: 0.6224 - 36s/epoch - 194ms/step
# Epoch 171/300
# 184/184 - 38s - loss: 2.3121 - categorical_accuracy: 0.6196 - 38s/epoch - 206ms/step
# Epoch 172/300
# 184/184 - 38s - loss: 2.3018 - categorical_accuracy: 0.6216 - 38s/epoch - 206ms/step
# Epoch 173/300
# 184/184 - 37s - loss: 2.2965 - categorical_accuracy: 0.6242 - 37s/epoch - 199ms/step
# Epoch 174/300
# 184/184 - 38s - loss: 2.3050 - categorical_accuracy: 0.6206 - 38s/epoch - 204ms/step
# Epoch 175/300
# 184/184 - 39s - loss: 2.2910 - categorical_accuracy: 0.6244 - 39s/epoch - 212ms/step
# Epoch 176/300
# 184/184 - 37s - loss: 2.2966 - categorical_accuracy: 0.6250 - 37s/epoch - 203ms/step
# Epoch 177/300
# 184/184 - 38s - loss: 2.2901 - categorical_accuracy: 0.6266 - 38s/epoch - 204ms/step
# Epoch 178/300
# 184/184 - 34s - loss: 2.2852 - categorical_accuracy: 0.6266 - 34s/epoch - 184ms/step
# Epoch 179/300
# 184/184 - 38s - loss: 2.2900 - categorical_accuracy: 0.6264 - 38s/epoch - 204ms/step
# Epoch 180/300
# 184/184 - 38s - loss: 2.2823 - categorical_accuracy: 0.6291 - 38s/epoch - 207ms/step
# Epoch 181/300
# 184/184 - 37s - loss: 2.2763 - categorical_accuracy: 0.6307 - 37s/epoch - 200ms/step
# Epoch 182/300
# 184/184 - 38s - loss: 2.2807 - categorical_accuracy: 0.6270 - 38s/epoch - 204ms/step
# Epoch 183/300
# 184/184 - 88s - loss: 2.2784 - categorical_accuracy: 0.6294 - 88s/epoch - 479ms/step
# Epoch 184/300
# 184/184 - 38s - loss: 2.2809 - categorical_accuracy: 0.6290 - 38s/epoch - 204ms/step
# Epoch 185/300
# 184/184 - 38s - loss: 2.2725 - categorical_accuracy: 0.6306 - 38s/epoch - 206ms/step
# Epoch 186/300
# 184/184 - 37s - loss: 2.2710 - categorical_accuracy: 0.6320 - 37s/epoch - 202ms/step
# Epoch 187/300
# 184/184 - 37s - loss: 2.2712 - categorical_accuracy: 0.6322 - 37s/epoch - 203ms/step
# Epoch 188/300
# 184/184 - 34s - loss: 2.2656 - categorical_accuracy: 0.6316 - 34s/epoch - 187ms/step
# Epoch 189/300
# 184/184 - 37s - loss: 2.2582 - categorical_accuracy: 0.6361 - 37s/epoch - 203ms/step
# Epoch 190/300
# 184/184 - 38s - loss: 2.2563 - categorical_accuracy: 0.6356 - 38s/epoch - 206ms/step
# Epoch 191/300
# 184/184 - 36s - loss: 2.2566 - categorical_accuracy: 0.6347 - 36s/epoch - 198ms/step
# Epoch 192/300
# 184/184 - 38s - loss: 2.2542 - categorical_accuracy: 0.6346 - 38s/epoch - 205ms/step
# Epoch 193/300
# 184/184 - 38s - loss: 2.2614 - categorical_accuracy: 0.6345 - 38s/epoch - 209ms/step
# Epoch 194/300
# 184/184 - 37s - loss: 2.2556 - categorical_accuracy: 0.6358 - 37s/epoch - 203ms/step
# Epoch 195/300
# 184/184 - 38s - loss: 2.2550 - categorical_accuracy: 0.6354 - 38s/epoch - 205ms/step
# Epoch 196/300
# 184/184 - 34s - loss: 2.2542 - categorical_accuracy: 0.6357 - 34s/epoch - 186ms/step
# Epoch 197/300
# 184/184 - 37s - loss: 2.2457 - categorical_accuracy: 0.6377 - 37s/epoch - 202ms/step
# Epoch 198/300
# 184/184 - 37s - loss: 2.2427 - categorical_accuracy: 0.6398 - 37s/epoch - 202ms/step
# Epoch 199/300
# 184/184 - 37s - loss: 2.2451 - categorical_accuracy: 0.6372 - 37s/epoch - 199ms/step
# Epoch 200/300
# 184/184 - 37s - loss: 2.2376 - categorical_accuracy: 0.6401 - 37s/epoch - 204ms/step
# Epoch 201/300
# 184/184 - 39s - loss: 2.2375 - categorical_accuracy: 0.6407 - 39s/epoch - 211ms/step
# Epoch 202/300
# 184/184 - 38s - loss: 2.2356 - categorical_accuracy: 0.6411 - 38s/epoch - 207ms/step
# Epoch 203/300
# 184/184 - 38s - loss: 2.2417 - categorical_accuracy: 0.6394 - 38s/epoch - 206ms/step
# Epoch 204/300
# 184/184 - 37s - loss: 2.2357 - categorical_accuracy: 0.6410 - 37s/epoch - 202ms/step
# Epoch 205/300
# 184/184 - 37s - loss: 2.2330 - categorical_accuracy: 0.6409 - 37s/epoch - 202ms/step
# Epoch 206/300
# 184/184 - 37s - loss: 2.2310 - categorical_accuracy: 0.6419 - 37s/epoch - 203ms/step
# Epoch 207/300
# 184/184 - 37s - loss: 2.2300 - categorical_accuracy: 0.6411 - 37s/epoch - 198ms/step
# Epoch 208/300
# 184/184 - 37s - loss: 2.2251 - categorical_accuracy: 0.6438 - 37s/epoch - 202ms/step
# Epoch 209/300
# 184/184 - 38s - loss: 2.2211 - categorical_accuracy: 0.6444 - 38s/epoch - 206ms/step
# Epoch 210/300
# 184/184 - 38s - loss: 2.2162 - categorical_accuracy: 0.6447 - 38s/epoch - 206ms/step
# Epoch 211/300
# 184/184 - 37s - loss: 2.2247 - categorical_accuracy: 0.6432 - 37s/epoch - 201ms/step
# Epoch 212/300
# 184/184 - 35s - loss: 2.2245 - categorical_accuracy: 0.6448 - 35s/epoch - 190ms/step
# Epoch 213/300
# 184/184 - 37s - loss: 2.2116 - categorical_accuracy: 0.6483 - 37s/epoch - 200ms/step
# Epoch 214/300
# 184/184 - 38s - loss: 2.2127 - categorical_accuracy: 0.6459 - 38s/epoch - 204ms/step
# Epoch 215/300
# 184/184 - 38s - loss: 2.2166 - categorical_accuracy: 0.6460 - 38s/epoch - 204ms/step
# Epoch 216/300
# 184/184 - 37s - loss: 2.2178 - categorical_accuracy: 0.6442 - 37s/epoch - 200ms/step
# Epoch 217/300
# 184/184 - 38s - loss: 2.2165 - categorical_accuracy: 0.6479 - 38s/epoch - 207ms/step
# Epoch 218/300
# 184/184 - 37s - loss: 2.2120 - categorical_accuracy: 0.6472 - 37s/epoch - 204ms/step
# Epoch 219/300
# 184/184 - 37s - loss: 2.2059 - categorical_accuracy: 0.6478 - 37s/epoch - 201ms/step
# Epoch 220/300
# 184/184 - 35s - loss: 2.2046 - categorical_accuracy: 0.6509 - 35s/epoch - 191ms/step
# Epoch 221/300
# 184/184 - 37s - loss: 2.2014 - categorical_accuracy: 0.6486 - 37s/epoch - 199ms/step
# Epoch 222/300
# 184/184 - 38s - loss: 2.1983 - categorical_accuracy: 0.6500 - 38s/epoch - 207ms/step
# Epoch 223/300
# 184/184 - 38s - loss: 2.2058 - categorical_accuracy: 0.6482 - 38s/epoch - 205ms/step
# Epoch 224/300
# 184/184 - 37s - loss: 2.1928 - categorical_accuracy: 0.6521 - 37s/epoch - 201ms/step
# Epoch 225/300
# 184/184 - 35s - loss: 2.1960 - categorical_accuracy: 0.6518 - 35s/epoch - 193ms/step
# Epoch 226/300
# 184/184 - 37s - loss: 2.1924 - categorical_accuracy: 0.6533 - 37s/epoch - 199ms/step
# Epoch 227/300
# 184/184 - 37s - loss: 2.1925 - categorical_accuracy: 0.6514 - 37s/epoch - 201ms/step
# Epoch 228/300
# 184/184 - 37s - loss: 2.1931 - categorical_accuracy: 0.6521 - 37s/epoch - 202ms/step
# Epoch 229/300
# 184/184 - 36s - loss: 2.1929 - categorical_accuracy: 0.6526 - 36s/epoch - 197ms/step
# Epoch 230/300
# 184/184 - 39s - loss: 2.1935 - categorical_accuracy: 0.6515 - 39s/epoch - 212ms/step
# Epoch 231/300
# 184/184 - 38s - loss: 2.1895 - categorical_accuracy: 0.6522 - 38s/epoch - 206ms/step
# Epoch 232/300
# 184/184 - 37s - loss: 2.1823 - categorical_accuracy: 0.6553 - 37s/epoch - 201ms/step
# Epoch 233/300
# 184/184 - 35s - loss: 2.1837 - categorical_accuracy: 0.6559 - 35s/epoch - 191ms/step
# Epoch 234/300
# 184/184 - 37s - loss: 2.1884 - categorical_accuracy: 0.6542 - 37s/epoch - 199ms/step
# Epoch 235/300
# 184/184 - 38s - loss: 2.1833 - categorical_accuracy: 0.6553 - 38s/epoch - 207ms/step
# Epoch 236/300
# 184/184 - 37s - loss: 2.1876 - categorical_accuracy: 0.6545 - 37s/epoch - 204ms/step
# Epoch 237/300
# 184/184 - 37s - loss: 2.1742 - categorical_accuracy: 0.6570 - 37s/epoch - 199ms/step
# Epoch 238/300
# 184/184 - 39s - loss: 2.1820 - categorical_accuracy: 0.6542 - 39s/epoch - 210ms/step
# Epoch 239/300
# 184/184 - 38s - loss: 2.1800 - categorical_accuracy: 0.6555 - 38s/epoch - 208ms/step
# Epoch 240/300
# 184/184 - 37s - loss: 2.1754 - categorical_accuracy: 0.6568 - 37s/epoch - 201ms/step
# Epoch 241/300
# 184/184 - 36s - loss: 2.1765 - categorical_accuracy: 0.6578 - 36s/epoch - 194ms/step
# Epoch 242/300
# 184/184 - 36s - loss: 2.1720 - categorical_accuracy: 0.6574 - 36s/epoch - 198ms/step
# Epoch 243/300
# 184/184 - 38s - loss: 2.1746 - categorical_accuracy: 0.6565 - 38s/epoch - 205ms/step
# Epoch 244/300
# 184/184 - 38s - loss: 2.1652 - categorical_accuracy: 0.6597 - 38s/epoch - 209ms/step
# Epoch 245/300
# 184/184 - 36s - loss: 2.1762 - categorical_accuracy: 0.6563 - 36s/epoch - 198ms/step
# Epoch 246/300
# 184/184 - 39s - loss: 2.1680 - categorical_accuracy: 0.6584 - 39s/epoch - 210ms/step
# Epoch 247/300
# 184/184 - 39s - loss: 2.1707 - categorical_accuracy: 0.6578 - 39s/epoch - 211ms/step
# Epoch 248/300
# 184/184 - 37s - loss: 2.1657 - categorical_accuracy: 0.6586 - 37s/epoch - 199ms/step
# Epoch 249/300
# 184/184 - 36s - loss: 2.1685 - categorical_accuracy: 0.6578 - 36s/epoch - 196ms/step
# Epoch 250/300
# 184/184 - 36s - loss: 2.1651 - categorical_accuracy: 0.6584 - 36s/epoch - 196ms/step
# Epoch 251/300
# 184/184 - 38s - loss: 2.1610 - categorical_accuracy: 0.6613 - 38s/epoch - 207ms/step
# Epoch 252/300
# 184/184 - 37s - loss: 2.1648 - categorical_accuracy: 0.6599 - 37s/epoch - 204ms/step
# Epoch 253/300
# 184/184 - 37s - loss: 2.1638 - categorical_accuracy: 0.6599 - 37s/epoch - 199ms/step
# Epoch 254/300
# 184/184 - 35s - loss: 2.1666 - categorical_accuracy: 0.6588 - 35s/epoch - 190ms/step
# Epoch 255/300
# 184/184 - 37s - loss: 2.1639 - categorical_accuracy: 0.6604 - 37s/epoch - 201ms/step
# Epoch 256/300
# 184/184 - 37s - loss: 2.1671 - categorical_accuracy: 0.6585 - 37s/epoch - 202ms/step
# Epoch 257/300
# 184/184 - 37s - loss: 2.1577 - categorical_accuracy: 0.6618 - 37s/epoch - 203ms/step
# Epoch 258/300
# 184/184 - 36s - loss: 2.1622 - categorical_accuracy: 0.6596 - 36s/epoch - 197ms/step
# Epoch 259/300
# 184/184 - 38s - loss: 2.1566 - categorical_accuracy: 0.6620 - 38s/epoch - 209ms/step
# Epoch 260/300
# 184/184 - 38s - loss: 2.1565 - categorical_accuracy: 0.6609 - 38s/epoch - 208ms/step
# Epoch 261/300
# 184/184 - 36s - loss: 2.1575 - categorical_accuracy: 0.6628 - 36s/epoch - 194ms/step
# Epoch 262/300
# 184/184 - 36s - loss: 2.1574 - categorical_accuracy: 0.6615 - 36s/epoch - 195ms/step
# Epoch 263/300
# 184/184 - 36s - loss: 2.1591 - categorical_accuracy: 0.6615 - 36s/epoch - 195ms/step
# Epoch 264/300
# 184/184 - 38s - loss: 2.1532 - categorical_accuracy: 0.6629 - 38s/epoch - 204ms/step
# Epoch 265/300
# 184/184 - 37s - loss: 2.1568 - categorical_accuracy: 0.6631 - 37s/epoch - 203ms/step
# Epoch 266/300
# 184/184 - 36s - loss: 2.1553 - categorical_accuracy: 0.6632 - 36s/epoch - 197ms/step
# Epoch 267/300
# 184/184 - 35s - loss: 2.1517 - categorical_accuracy: 0.6629 - 35s/epoch - 193ms/step
# Epoch 268/300
# 184/184 - 36s - loss: 2.1486 - categorical_accuracy: 0.6635 - 36s/epoch - 195ms/step
# Epoch 269/300
# 184/184 - 37s - loss: 2.1545 - categorical_accuracy: 0.6625 - 37s/epoch - 200ms/step
# Epoch 270/300
# 184/184 - 38s - loss: 2.1548 - categorical_accuracy: 0.6613 - 38s/epoch - 204ms/step
# Epoch 271/300
# 184/184 - 36s - loss: 2.1510 - categorical_accuracy: 0.6630 - 36s/epoch - 197ms/step
# Epoch 272/300
# 184/184 - 38s - loss: 2.1506 - categorical_accuracy: 0.6630 - 38s/epoch - 207ms/step
# Epoch 273/300
# 184/184 - 38s - loss: 2.1485 - categorical_accuracy: 0.6641 - 38s/epoch - 207ms/step
# Epoch 274/300
# 184/184 - 36s - loss: 2.1540 - categorical_accuracy: 0.6614 - 36s/epoch - 196ms/step
# Epoch 275/300
# 184/184 - 36s - loss: 2.1502 - categorical_accuracy: 0.6640 - 36s/epoch - 196ms/step
# Epoch 276/300
# 184/184 - 36s - loss: 2.1447 - categorical_accuracy: 0.6648 - 36s/epoch - 194ms/step
# Epoch 277/300
# 184/184 - 38s - loss: 2.1498 - categorical_accuracy: 0.6639 - 38s/epoch - 206ms/step
# Epoch 278/300
# 184/184 - 38s - loss: 2.1515 - categorical_accuracy: 0.6623 - 38s/epoch - 209ms/step
# Epoch 279/300
# 184/184 - 35s - loss: 2.1505 - categorical_accuracy: 0.6636 - 35s/epoch - 192ms/step
# Epoch 280/300
# 184/184 - 36s - loss: 2.1530 - categorical_accuracy: 0.6631 - 36s/epoch - 195ms/step
# Epoch 281/300
# 184/184 - 36s - loss: 2.1498 - categorical_accuracy: 0.6625 - 36s/epoch - 195ms/step
# Epoch 282/300
# 184/184 - 37s - loss: 2.1534 - categorical_accuracy: 0.6626 - 37s/epoch - 204ms/step
# Epoch 283/300
# 184/184 - 39s - loss: 2.1435 - categorical_accuracy: 0.6644 - 39s/epoch - 211ms/step
# Epoch 284/300
# 184/184 - 36s - loss: 2.1435 - categorical_accuracy: 0.6638 - 36s/epoch - 194ms/step
# Epoch 285/300
# 184/184 - 39s - loss: 2.1453 - categorical_accuracy: 0.6637 - 39s/epoch - 210ms/step
# Epoch 286/300
# 184/184 - 39s - loss: 2.1434 - categorical_accuracy: 0.6649 - 39s/epoch - 214ms/step
# Epoch 287/300
# 184/184 - 35s - loss: 2.1435 - categorical_accuracy: 0.6641 - 35s/epoch - 193ms/step
# Epoch 288/300
# 184/184 - 36s - loss: 2.1430 - categorical_accuracy: 0.6659 - 36s/epoch - 195ms/step
# Epoch 289/300
# 184/184 - 35s - loss: 2.1497 - categorical_accuracy: 0.6626 - 35s/epoch - 193ms/step
# Epoch 290/300
# 184/184 - 38s - loss: 2.1481 - categorical_accuracy: 0.6647 - 38s/epoch - 205ms/step
# Epoch 291/300
# 184/184 - 39s - loss: 2.1435 - categorical_accuracy: 0.6646 - 39s/epoch - 210ms/step
# Epoch 292/300
# 184/184 - 36s - loss: 2.1468 - categorical_accuracy: 0.6639 - 36s/epoch - 194ms/step
# Epoch 293/300
# 184/184 - 39s - loss: 2.1515 - categorical_accuracy: 0.6639 - 39s/epoch - 212ms/step
# Epoch 294/300
# 184/184 - 39s - loss: 2.1471 - categorical_accuracy: 0.6646 - 39s/epoch - 212ms/step
# Epoch 295/300
# 184/184 - 35s - loss: 2.1455 - categorical_accuracy: 0.6641 - 35s/epoch - 192ms/step
# Epoch 296/300
# 184/184 - 37s - loss: 2.1492 - categorical_accuracy: 0.6641 - 37s/epoch - 200ms/step
# Epoch 297/300
# 184/184 - 36s - loss: 2.1434 - categorical_accuracy: 0.6637 - 36s/epoch - 193ms/step
# Epoch 298/300
# 184/184 - 37s - loss: 2.1529 - categorical_accuracy: 0.6643 - 37s/epoch - 203ms/step
# Epoch 299/300
# 184/184 - 38s - loss: 2.1422 - categorical_accuracy: 0.6661 - 38s/epoch - 206ms/step
# Epoch 300/300
# 184/184 - 35s - loss: 2.1469 - categorical_accuracy: 0.6654 - 35s/epoch - 188ms/step

# %%
# CFG.seed = 43
# CFG.comment = f'islr-fp16-192-8-seed{CFG.seed}'
# train_folds(CFG, ['all'], summary=False)

# %%
# CFG.seed = 44
# CFG.comment = f'islr-fp16-192-8-seed{CFG.seed}'
# train_folds(CFG, ['all'], summary=False)

# %%
# CFG.seed = 45
# CFG.comment = f'islr-fp16-192-8-seed{CFG.seed}'
# train_folds(CFG, ['all'], summary=False)
